# %%
# %run run.py
# Out:
# ############################################
#          SECTION: DATA SOURCES USED
# ############################################
#
# >> Data for The Scenes
# +---------+------------------------------------------------------------+------------------------------------+--------------------+--------------------+
# | Scene   | Cast                                                       | Location                           | Latitude           | Longitude          |
# |---------+------------------------------------------------------------+------------------------------------+--------------------+--------------------|
# | 1A      | IRAH, MANTO, WAWAN                                         | -                                  | -                  | -                  |
# | 1B      | IRAH, MANTO, WAWAN                                         | -                                  | -                  | -                  |
# ...
